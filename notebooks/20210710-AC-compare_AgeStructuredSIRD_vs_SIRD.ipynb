# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#AgeStructuredSIRD-vs-SIRD" data-toc-modified-id="AgeStructuredSIRD-vs-SIRD-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>AgeStructuredSIRD vs SIRD</a></span><ul class="toc-item"><li><span><a href="#Comparisons-vs-simple-SIRD-model" data-toc-modified-id="Comparisons-vs-simple-SIRD-model-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Comparisons vs simple SIRD model</a></span><ul class="toc-item"><li><span><a href="#SIRD" data-toc-modified-id="SIRD-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>SIRD</a></span></li><li><span><a href="#AgeStructuredSIRD---two-equivalent-populations" data-toc-modified-id="AgeStructuredSIRD---two-equivalent-populations-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>AgeStructuredSIRD - two equivalent populations</a></span></li><li><span><a href="#AgeStructuredSIRD---two-non-mixing-populations-(zero-transmissability-between-populations)" data-toc-modified-id="AgeStructuredSIRD---two-non-mixing-populations-(zero-transmissability-between-populations)-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>AgeStructuredSIRD - two non-mixing populations (zero transmissability between populations)</a></span></li></ul></li><li><span><a href="#AgeStructuredSIRD" data-toc-modified-id="AgeStructuredSIRD-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>AgeStructuredSIRD</a></span><ul class="toc-item"><li><span><a href="#Complex-example" data-toc-modified-id="Complex-example-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Complex example</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # AgeStructuredSIRD vs SIRD
#
# This notebook confirms that the AgeStructuredSIRD model returns equivalent results to the simple base SIRD model.

# %%
# %load_ext autoreload
# %autoreload 2

from Eir import AgeStructuredSIRD, SIRD
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.style.use("../style.mplstyle")

# %%
days, dt = 31, 0.1

# %% [markdown]
# ## Comparisons vs simple SIRD model
#
# ### SIRD

# %%
S0 = 10_000_000
I0 = 10
R0 = 0
beta = 1.5
gamma = 0.15
omega = 0.01

# %%
sim = SIRD(S0=S0, I0=I0, R0=R0, beta=beta, gamma=gamma, omega=omega)
df, fig = sim.run(days, dt)
fig;

# %%
df
# Out:
#      Days   Susceptible       Infected       Removed         Deaths
# 0     0.0  1.000000e+07      10.000000  0.000000e+00       0.000000
# 1     0.1  9.999999e+06      11.339999  1.500000e-01       0.010000
# 2     0.2  9.999997e+06      12.859557  3.201000e-01       0.021340
# 3     0.3  9.999995e+06      14.582735  5.129933e-01       0.034200
# 4     0.4  9.999993e+06      16.536818  7.317343e-01       0.048782
# ..    ...           ...            ...           ...            ...
# 306  30.6  7.081048e+02  432203.398384  8.969155e+06  597943.656053
# 307  30.7  7.032221e+02  425293.026638  8.975638e+06  598375.859452
# 308  30.8  6.984505e+02  418493.109863  8.982017e+06  598801.152478
# 309  30.9  6.937868e+02  411801.883815  8.988295e+06  599219.645588
# 310  31.0  6.892281e+02  405217.612377  8.994472e+06  599631.447472
#
# [311 rows x 5 columns]

# %% [markdown]
# ### AgeStructuredSIRD - two equivalent populations

# %%
labels_as = ["A", "B"]
S0_as = [int(S0 / 2), int(S0 / 2)]
I0_as = [int(I0 / 2), int(I0 / 2)]
R0_as = [int(R0 / 2), int(R0 / 2)]
beta_as = np.array(
    [
        [beta, beta],
        [beta, beta],
    ]
)
gamma_as = [gamma, gamma]
omega_as = [omega, omega]

sim = AgeStructuredSIRD(labels_as, beta_as, gamma_as, omega_as, S0_as, I0_as, R0_as)
df_as, fig_as = sim.run(days, dt)
fig_as

# %%
# same results as base SIRD model
pd.testing.assert_frame_equal(df, df_as.iloc[:, :5])

# %% [markdown]
# ### AgeStructuredSIRD - two non-mixing populations (zero transmissability between populations)
#
# Population 'A' is equivalent to base SIRD model.

# %%
labels_as = ["A", "B"]
S0_as = [10_000_000, 8_000_000]
I0_as = [10, 8]
R0_as = [0, 0]
beta_as = np.array([[beta, beta], [beta, beta]])
gamma_as = [gamma, gamma]
omega_as = [omega, omega]
N = np.array(S0_as) + np.array(I0_as) + np.array(R0_as)

sim = AgeStructuredSIRD(labels_as, beta_as, gamma_as, omega_as, S0_as, I0_as, R0_as)
df_as, fig_as = sim.run(days, dt)
fig_as

# %%
# population A has the same results as base SIRD model
pd.testing.assert_frame_equal(
    df_as.iloc[:, 5:9].rename(
        columns={
            "Susceptible_A": "Susceptible",
            "Infected_A": "Infected",
            "Removed_A": "Removed",
            "Deaths_A": "Deaths",
        }
    ),
    df.iloc[:, 1:],
)

# %% [markdown]
# ## AgeStructuredSIRD
#
# ### Complex example

# %%
labels = ["<40", "40-80", ">80"]
S0 = [32_000_000, 30_000_000, 5_000_000]
I0 = [32, 30, 5]
R0 = [0, 0, 0]
beta = np.array(
    [
        [2.5, 1.5, 0.3],
        [1.5, 1.9, 0.5],
        [0.3, 0.5, 1.1],
    ]
)
gamma = [0.1, 0.1, 0.1]
omega = [0.0003, 0.002, 0.008]
N = np.array(S0) + np.array(I0) + np.array(R0)

sim = AgeStructuredSIRD(labels, beta, gamma, omega, S0, I0, R0)
df, fig = sim.run(days, dt)
fig
